# %% [markdown]
# ### Dispenser Usage
#
# #### Background
# - Detecting Hand Hygiene Dispenser Use
# - See: https://docs.google.com/document/d/1iPzdrs4tEbltL9iHykD_KKQxFjcWRBDu5fH6YkuxFFM/edit
#
# ##### Notebook
# - Trains a model to predict "is_clean"
#    - ResNet-50 base model
#    - ConvLSTM2D layer
#    - AvgPool
#    - Dense (sigmoid)
#
# ##### Results
# - Train Accuracy: 96.7%
# - Val Accuracy: 80.4%
# - 27 epochs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://aicare.stanford.edu/sep2020.tar.gz
# Out:
# --2020-09-17 19:01:06--  https://aicare.stanford.edu/sep2020.tar.gz
# Resolving aicare.stanford.edu (aicare.stanford.edu)... 171.64.68.86
# Connecting to aicare.stanford.edu (aicare.stanford.edu)|171.64.68.86|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 224617454 (214M) [application/x-gzip]
# Saving to: ‘sep2020.tar.gz’
#
# sep2020.tar.gz      100%[===================>] 214.21M  3.89MB/s    in 49s
#
# 2020-09-17 19:01:55 (4.40 MB/s) - ‘sep2020.tar.gz’ saved [224617454/224617454]

# %%
# !tar -xzf sep2020.tar.gz

# %%
# !ls hh_data
# Out:
# labels.json  mp4  npy

# %%
# !nvidia-smi
# Out:
# Thu Sep 17 19:02:06 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     8W /  75W |      0MiB /  7611MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Load the labels

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import cv2
from os import listdir
from os.path import isfile, join, exists
from sklearn.model_selection import train_test_split

# %%
import json

video_to_room = {}
video_to_class = {}
with open("hh_data/labels.json", "r") as f:
    labels_obj = json.load(f)
    for k, v in labels_obj.items():
        video_to_room[k] = v["room"]
        video_to_class[k] = v["is_clean"]
classes = list(set(video_to_class.values()))

video_ids = []
frame_numbers = []
# Because some videos are being held back, we are just going to filter for videos we know about
for k in video_to_class.keys():
    if exists("hh_data/npy/" + k + ".npy"):
        video_ids.append(k)
        video_obj = np.load("hh_data/npy/" + k + ".npy")
        frame_numbers.append(video_obj.shape[0])
print(f"Max frames: {np.max(frame_numbers)}")
print(f"Min frames: {np.min(frame_numbers)}")
print(f"Avg frames: {np.mean(frame_numbers)}")
print(f"Avg frames: {np.median(frame_numbers)}")
# Out:
# Max frames: 200
# Min frames: 5
# Avg frames: 32.562913907284766
# Avg frames: 25.0

# %%
NUM_FRAMES = 24
BATCH_SIZE = 16
IMG_HEIGHT = 240
IMG_WIDTH = 320

def normalize(a):
    return (255*(a/np.max(a))).astype(int)

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, video_dir, video_ids, video_to_class, classes, num_frames=NUM_FRAMES, batch_size=32, shuffle=True):
        self.batch_size = batch_size
        self.num_frames = num_frames
        self.video_dir = video_dir
        self.video_ids = video_ids
        self.video_to_class = video_to_class
        self.shuffle = shuffle
        self.classes = classes
        self.on_epoch_end()
        print(f"Found {len(self.video_ids)} videos belonging to {len(self.classes)} classes.")

    def __len__(self):
        """
        Denotes the number of batches per epoch
        """
        return int(np.floor(len(self.video_ids) / self.batch_size))

    def __getitem__(self, index):
        """
        Generate one batch of data
        """
        video_ids = self.video_ids[index*self.batch_size:(index+1)*self.batch_size]

        # Depth videos are "greyscale" but for transfer learning we need three channels
        X = np.zeros((len(video_ids), self.num_frames, IMG_HEIGHT, IMG_WIDTH, 3), dtype=np.float32)
        y = []
        i = 0
        for video_id in video_ids:
            video = np.load(join(self.video_dir, video_id + ".npy"))
            curr_frames = video.shape[0]

            # Convert npy to float32 to avoid processing problems
            # num_frames, 240, 320
            base_video = np.zeros((self.num_frames, IMG_HEIGHT, IMG_WIDTH), dtype=np.float32)

            # Number of frames are uneven, so we will evenly sample across all video frames
            # if the number of frames are more than the frames we want to use
            if self.num_frames < curr_frames:
                indices = np.round(np.linspace(0, curr_frames - 1, self.num_frames)).astype(int)
                base_video[:, :, :] = video[indices, :, :]
            else:
                base_video[:min(curr_frames, self.num_frames), :, :] = video[:min(curr_frames, self.num_frames), :, :].astype(np.float32)

            # Repeat the depth image three times to simulate RGB
            video = base_video[:, :, :, np.newaxis]
            video = normalize(video)
            video = np.repeat(video, 3, -1)

            X[i, :, :, :] = video

            # Classes are 0 or 1
            y.append(self.video_to_class[video_id])

            i += 1

        y = np.array(y)

        return X, tf.keras.utils.to_categorical(y, num_classes=len(self.classes))

    def on_epoch_end(self):
        """
        Shuffles the data upon completion of a full epoch 
        """
        if self.shuffle == True:
            np.random.shuffle(self.video_ids)

# %%
#
# CONFIGURATION
#
# Define any constants for the model here
#

BATCH_SIZE = 8

# %%
video_ids_train, video_ids_val = train_test_split(video_ids, test_size=0.2)

train_generator = DataGenerator("hh_data/npy", video_ids_train, video_to_class, classes, batch_size=BATCH_SIZE)

validation_generator = DataGenerator("hh_data/npy", video_ids_val, video_to_class, classes, batch_size=BATCH_SIZE)
# Out:
# Found 241 videos belonging to 2 classes.
# Found 61 videos belonging to 2 classes.

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(30, 30))
    for i in range(4):
        ax = plt.subplot(5, 5, i+1)
        plt.imshow(image_batch[i, 0]) # first frame from each video
        plt.title(label_batch[i])
        plt.axis('off')
image_batch, label_batch = train_generator.__getitem__(0)
image_batch = (image_batch / (np.max(image_batch, axis=0) + 0.001))
show_batch(image_batch, label_batch)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
def show_frames_batch(image_batch, label_batch):
    plt.figure(figsize=(60, 60))
    for i in range(NUM_FRAMES):
        ax = plt.subplot(1, NUM_FRAMES, i+1)
        plt.imshow(image_batch[7, i]) # frames from first video
        plt.title(label_batch[7])
        plt.axis('off')
image_batch, label_batch = train_generator.__getitem__(0)
image_batch = (image_batch / (np.max(image_batch, axis=0) + 0.001))
show_frames_batch(image_batch, label_batch)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
from pathlib import Path

BASE_NAME = "resnet50"
MODEL_NAME = "dispenser-v6"
IMG_SHAPE = (IMG_HEIGHT, IMG_WIDTH, 3)

Path(f"drive/My Drive/svl-pac/checkpoints/{MODEL_NAME}").mkdir(parents=True, exist_ok=True)
checkpoint_path = "drive/My Drive/svl-pac/checkpoints/" + MODEL_NAME + "/cp-{epoch:04d}.ckpt"

# Create a callback that saves the model's weights every 1 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1,
    save_weights_only=True,
    period=1)

def create_model(inputs):
    base_model = get_base_model(BASE_NAME)
    base_model.trainable = False

    x = tf.keras.layers.TimeDistributed(base_model)(inputs)
    x = tf.keras.layers.ConvLSTM2D(filters=64, kernel_size=(3, 3), padding='same', return_sequences=True)(x)
    x = tf.keras.layers.GlobalAveragePooling3D()(x)
    # x_long = tf.keras.layers.Flatten()(x)
    # x_long = tf.keras.layers.Dense(40, activation='relu')(x_long)
    # x = tf.keras.layers.Add()([x, x_long])
    x = tf.keras.layers.Dense(2, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=x)
    model.compile(optimizer='adam',
                  loss = 'categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def get_base_model(model_name="resnet50"):
    if model_name == 'inception_v3':
        return tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'xception':
        return tf.keras.applications.Xception(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'vgg16':
        return tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'vgg19':
        return tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'resnet50':
        return tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    else:
        raise ValueError(f"Cannot find base model {model_name}")

inputs = tf.keras.Input(shape=(NUM_FRAMES, IMG_HEIGHT, IMG_WIDTH, 3))
model = create_model(inputs)
model.summary()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 24, 240, 320, 3)] 0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 8, 10, 2048)   23587712
# _________________________________________________________________
# conv_lst_m2d (ConvLSTM2D)    (None, 24, 8, 10, 64)     4866304
# _________________________________________________________________
# global_average_pooling3d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 130
# =================================================================
# Total params: 28,454,146
# Trainable params: 4,866,434
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
initial_epochs = 10

# Try evaluating the model for a few rounds
loss, accuracy = model.evaluate(validation_generator, steps = 3)
# Out:
# 3/3 [==============================] - 2s 713ms/step - loss: 0.6944 - accuracy: 0.5000

# %%
validation_generator.batch_size
# Out:
# 16

# %%
import pickle
history = model.fit(
          train_generator,
          epochs=initial_epochs,
          callbacks=[cp_callback],
          validation_data=validation_generator
)

# with open(f"drive/My Drive/checkpoints/{MODEL_NAME}/history.pkl", 'wb') as handle:
#     pickle.dump(history.history, handle)
# Out:
# Epoch 1/10
# 30/30 [==============================] - ETA: 0s - loss: 0.7730 - accuracy: 0.5708
# Epoch 00001: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0001.ckpt
# 30/30 [==============================] - 46s 2s/step - loss: 0.7730 - accuracy: 0.5708 - val_loss: 0.6645 - val_accuracy: 0.5536
# Epoch 2/10
# 30/30 [==============================] - ETA: 0s - loss: 0.6294 - accuracy: 0.6375
# Epoch 00002: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0002.ckpt
# 30/30 [==============================] - 46s 2s/step - loss: 0.6294 - accuracy: 0.6375 - val_loss: 0.6410 - val_accuracy: 0.5893
# Epoch 3/10
# 30/30 [==============================] - ETA: 0s - loss: 0.6022 - accuracy: 0.6750
# Epoch 00003: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0003.ckpt
# 30/30 [==============================] - 46s 2s/step - loss: 0.6022 - accuracy: 0.6750 - val_loss: 0.6674 - val_accuracy: 0.5179
# Epoch 4/10
# 30/30 [==============================] - ETA: 0s - loss: 0.6012 - accuracy: 0.6708
# Epoch 00004: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0004.ckpt
# 30/30 [==============================] - 48s 2s/step - loss: 0.6012 - accuracy: 0.6708 - val_loss: 0.6242 - val_accuracy: 0.6429
# Epoch 5/10
# 30/30 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.6708
# Epoch 00005: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0005.ckpt
# 30/30 [==============================] - 47s 2s/step - loss: 0.5876 - accuracy: 0.6708 - val_loss: 0.5853 - val_accuracy: 0.7143
# Epoch 6/10
# 30/30 [==============================] - ETA: 0s - loss: 0.5645 - accuracy: 0.7375
# Epoch 00006: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0006.ckpt
# 30/30 [==============================] - 47s 2s/step - loss: 0.5645 - accuracy: 0.7375 - val_loss: 0.6408 - val_accuracy: 0.6250
# Epoch 7/10
# 30/30 [==============================] - ETA: 0s - loss: 0.5526 - accuracy: 0.7292
# Epoch 00007: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0007.ckpt
# 30/30 [==============================] - 47s 2s/step - loss: 0.5526 - accuracy: 0.7292 - val_loss: 0.5687 - val_accuracy: 0.6964
# Epoch 8/10
# 30/30 [==============================] - ETA: 0s - loss: 0.5515 - accuracy: 0.7167
# Epoch 00008: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0008.ckpt
# 30/30 [==============================] - 47s 2s/step - loss: 0.5515 - accuracy: 0.7167 - val_loss: 0.5968 - val_accuracy: 0.7143
# Epoch 9/10
# 30/30 [==============================] - ETA: 0s - loss: 0.5111 - accuracy: 0.7708
# Epoch 00009: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0009.ckpt
# 30/30 [==============================] - 48s 2s/step - loss: 0.5111 - accuracy: 0.7708 - val_loss: 0.5648 - val_accuracy: 0.7143
# Epoch 10/10
# 30/30 [==============================] - ETA: 0s - loss: 0.4839 - accuracy: 0.7750
# Epoch 00010: saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v6/cp-0010.ckpt
# 30/30 [==============================] - 47s 2s/step - loss: 0.4839 - accuracy: 0.7750 - val_loss: 0.5344 - val_accuracy: 0.7857

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

model.save(f"drive/My Drive/svl-pac/checkpoints/{MODEL_NAME}/m1.h5")

# %% [markdown]
# ### Train for longer

# %%
from pathlib import Path

BASE_NAME = "resnet50"
MODEL_NAME = "dispenser-v7"
IMG_SHAPE = (IMG_HEIGHT, IMG_WIDTH, 3)

Path(f"drive/My Drive/svl-pac/checkpoints/{MODEL_NAME}").mkdir(parents=True, exist_ok=True)
checkpoint_path = "drive/My Drive/svl-pac/checkpoints/" + MODEL_NAME + "/cp-{epoch:04d}.ckpt"

# Create a callback that saves the model's weights every 1 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1,
    save_weights_only=False,
    save_best_only=True,
    period=1)

def create_model(inputs):
    base_model = get_base_model(BASE_NAME)
    base_model.trainable = False

    x = tf.keras.layers.TimeDistributed(base_model)(inputs)
    x = tf.keras.layers.ConvLSTM2D(filters=64, kernel_size=(3, 3), padding='same', return_sequences=True)(x)
    x = tf.keras.layers.GlobalAveragePooling3D()(x)
    x = tf.keras.layers.Dense(2, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=x)
    model.compile(optimizer='adam',
                  loss = 'categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def get_base_model(model_name="resnet50"):
    if model_name == 'inception_v3':
        return tf.keras.applications.InceptionV3(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'xception':
        return tf.keras.applications.Xception(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'vgg16':
        return tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'vgg19':
        return tf.keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    elif model_name == 'resnet50':
        return tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    else:
        raise ValueError(f"Cannot find base model {model_name}")

inputs = tf.keras.Input(shape=(NUM_FRAMES, IMG_HEIGHT, IMG_WIDTH, 3))
model = create_model(inputs)
model.summary()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 24, 240, 320, 3)] 0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 24, 8, 10, 2048)   23587712
# _________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)  (None, 24, 8, 10, 64)     4866304
# _________________________________________________________________
# global_average_pooling3d_2 ( (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 28,454,146
# Trainable params: 4,866,434
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
history = model.fit(
          train_generator,
          epochs=60,
          callbacks=[cp_callback],
          validation_data=validation_generator
)
# Out:
# Epoch 1/60
# 30/30 [==============================] - ETA: 0s - loss: 0.7644 - accuracy: 0.5708
# Epoch 00001: val_loss improved from inf to 0.65979, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0001.ckpt
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0001.ckpt/assets
# 30/30 [==============================] - 77s 3s/step - loss: 0.7644 - accuracy: 0.5708 - val_loss: 0.6598 - val_accuracy: 0.5893
# Epoch 2/60
# 30/30 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.5833
# Epoch 00002: val_loss improved from 0.65979 to 0.65518, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0002.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0002.ckpt/assets
# 30/30 [==============================] - 77s 3s/step - loss: 0.6485 - accuracy: 0.5833 - val_loss: 0.6552 - val_accuracy: 0.6071
# Epoch 3/60
# 30/30 [==============================] - ETA: 0s - loss: 0.6233 - accuracy: 0.6333
# Epoch 00003: val_loss improved from 0.65518 to 0.65320, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0003.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0003.ckpt/assets
# 30/30 [==============================] - 77s 3s/step - loss: 0.6233 - accuracy: 0.6333 - val_loss: 0.6532 - val_accuracy: 0.6429
# Epoch 4/60
# 30/30 [==============================] - ETA: 0s - loss: 0.6131 - accuracy: 0.6208
# Epoch 00004: val_loss improved from 0.65320 to 0.61640, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0004.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0004.ckpt/assets
# 30/30 [==============================] - 78s 3s/step - loss: 0.6131 - accuracy: 0.6208 - val_loss: 0.6164 - val_accuracy: 0.7143
# Epoch 5/60
# 30/30 [==============================] - ETA: 0s - loss: 0.6076 - accuracy: 0.6500
# Epoch 00005: val_loss did not improve from 0.61640
# 30/30 [==============================] - 46s 2s/step - loss: 0.6076 - accuracy: 0.6500 - val_loss: 0.6259 - val_accuracy: 0.6964
# Epoch 6/60
# 30/30 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.6417
# Epoch 00006: val_loss did not improve from 0.61640
# 30/30 [==============================] - 46s 2s/step - loss: 0.6020 - accuracy: 0.6417 - val_loss: 0.6175 - val_accuracy: 0.6786
# Epoch 7/60
# 30/30 [==============================] - ETA: 0s - loss: 0.5847 - accuracy: 0.6667
# Epoch 00007: val_loss did not improve from 0.61640
# 30/30 [==============================] - 46s 2s/step - loss: 0.5847 - accuracy: 0.6667 - val_loss: 0.6218 - val_accuracy: 0.6964
# Epoch 8/60
# 30/30 [==============================] - ETA: 0s - loss: 0.5765 - accuracy: 0.7000
# Epoch 00008: val_loss improved from 0.61640 to 0.61295, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0008.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0008.ckpt/assets
# 30/30 [==============================] - 77s 3s/step - loss: 0.5765 - accuracy: 0.7000 - val_loss: 0.6130 - val_accuracy: 0.6607
# Epoch 9/60
# 30/30 [==============================] - ETA: 0s - loss: 0.5612 - accuracy: 0.7167
# Epoch 00009: val_loss improved from 0.61295 to 0.59140, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0009.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0009.ckpt/assets
# 30/30 [==============================] - 77s 3s/step - loss: 0.5612 - accuracy: 0.7167 - val_loss: 0.5914 - val_accuracy: 0.7143
# Epoch 10/60
# 30/30 [==============================] - ETA: 0s - loss: 0.5405 - accuracy: 0.7333
# Epoch 00010: val_loss improved from 0.59140 to 0.55094, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0010.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0010.ckpt/assets
# 30/30 [==============================] - 77s 3s/step - loss: 0.5405 - accuracy: 0.7333 - val_loss: 0.5509 - val_accuracy: 0.7143
# Epoch 11/60
# 30/30 [==============================] - ETA: 0s - loss: 0.5257 - accuracy: 0.7292
# Epoch 00011: val_loss did not improve from 0.55094
# 30/30 [==============================] - 46s 2s/step - loss: 0.5257 - accuracy: 0.7292 - val_loss: 0.5783 - val_accuracy: 0.6607
# Epoch 12/60
# 30/30 [==============================] - ETA: 0s - loss: 0.4925 - accuracy: 0.7750
# Epoch 00012: val_loss did not improve from 0.55094
# 30/30 [==============================] - 46s 2s/step - loss: 0.4925 - accuracy: 0.7750 - val_loss: 0.7004 - val_accuracy: 0.6250
# Epoch 13/60
# 30/30 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.7833
# Epoch 00013: val_loss improved from 0.55094 to 0.52324, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0013.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0013.ckpt/assets
# 30/30 [==============================] - 78s 3s/step - loss: 0.4779 - accuracy: 0.7833 - val_loss: 0.5232 - val_accuracy: 0.6964
# Epoch 14/60
# 30/30 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.7750
# Epoch 00014: val_loss did not improve from 0.52324
# 30/30 [==============================] - 46s 2s/step - loss: 0.4590 - accuracy: 0.7750 - val_loss: 0.5874 - val_accuracy: 0.6607
# Epoch 15/60
# 30/30 [==============================] - ETA: 0s - loss: 0.4131 - accuracy: 0.8333
# Epoch 00015: val_loss did not improve from 0.52324
# 30/30 [==============================] - 46s 2s/step - loss: 0.4131 - accuracy: 0.8333 - val_loss: 0.5531 - val_accuracy: 0.7321
# Epoch 16/60
# 30/30 [==============================] - ETA: 0s - loss: 0.4133 - accuracy: 0.8417
# Epoch 00016: val_loss did not improve from 0.52324
# 30/30 [==============================] - 46s 2s/step - loss: 0.4133 - accuracy: 0.8417 - val_loss: 0.5334 - val_accuracy: 0.7500
# Epoch 17/60
# 30/30 [==============================] - ETA: 0s - loss: 0.3581 - accuracy: 0.8667
# Epoch 00017: val_loss improved from 0.52324 to 0.45569, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0017.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0017.ckpt/assets
# 30/30 [==============================] - 78s 3s/step - loss: 0.3581 - accuracy: 0.8667 - val_loss: 0.4557 - val_accuracy: 0.7679
# Epoch 18/60
# 30/30 [==============================] - ETA: 0s - loss: 0.3383 - accuracy: 0.8458
# Epoch 00018: val_loss did not improve from 0.45569
# 30/30 [==============================] - 46s 2s/step - loss: 0.3383 - accuracy: 0.8458 - val_loss: 0.5416 - val_accuracy: 0.6964
# Epoch 19/60
# 30/30 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.8917
# Epoch 00019: val_loss did not improve from 0.45569
# 30/30 [==============================] - 47s 2s/step - loss: 0.3073 - accuracy: 0.8917 - val_loss: 0.4977 - val_accuracy: 0.7500
# Epoch 20/60
# 30/30 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.9125
# Epoch 00020: val_loss did not improve from 0.45569
# 30/30 [==============================] - 46s 2s/step - loss: 0.2705 - accuracy: 0.9125 - val_loss: 0.6087 - val_accuracy: 0.7321
# Epoch 21/60
# 30/30 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.9375
# Epoch 00021: val_loss did not improve from 0.45569
# 30/30 [==============================] - 46s 2s/step - loss: 0.2322 - accuracy: 0.9375 - val_loss: 0.5614 - val_accuracy: 0.6964
# Epoch 22/60
# 30/30 [==============================] - ETA: 0s - loss: 0.2176 - accuracy: 0.9333
# Epoch 00022: val_loss did not improve from 0.45569
# 30/30 [==============================] - 46s 2s/step - loss: 0.2176 - accuracy: 0.9333 - val_loss: 0.5038 - val_accuracy: 0.7500
# Epoch 23/60
# 30/30 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9625
# Epoch 00023: val_loss did not improve from 0.45569
# 30/30 [==============================] - 46s 2s/step - loss: 0.1772 - accuracy: 0.9625 - val_loss: 0.5013 - val_accuracy: 0.7143
# Epoch 24/60
# 30/30 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9542
# Epoch 00024: val_loss did not improve from 0.45569
# 30/30 [==============================] - 46s 2s/step - loss: 0.1556 - accuracy: 0.9542 - val_loss: 0.5897 - val_accuracy: 0.6964
# Epoch 25/60
# 30/30 [==============================] - ETA: 0s - loss: 0.1238 - accuracy: 0.9708
# Epoch 00025: val_loss did not improve from 0.45569
# 30/30 [==============================] - 46s 2s/step - loss: 0.1238 - accuracy: 0.9708 - val_loss: 0.5497 - val_accuracy: 0.7321
# Epoch 26/60
# 30/30 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9417
# Epoch 00026: val_loss did not improve from 0.45569
# 30/30 [==============================] - 46s 2s/step - loss: 0.1630 - accuracy: 0.9417 - val_loss: 0.5575 - val_accuracy: 0.7500
# Epoch 27/60
# 30/30 [==============================] - ETA: 0s - loss: 0.1507 - accuracy: 0.9667
# Epoch 00027: val_loss improved from 0.45569 to 0.44921, saving model to drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0027.ckpt
# INFO:tensorflow:Assets written to: drive/My Drive/svl-pac/checkpoints/dispenser-v7/cp-0027.ckpt/assets
# 30/30 [==============================] - 78s 3s/step - loss: 0.1507 - accuracy: 0.9667 - val_loss: 0.4492 - val_accuracy: 0.8036
# Epoch 28/60
# 30/30 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9583
# Epoch 00028: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.1354 - accuracy: 0.9583 - val_loss: 0.5014 - val_accuracy: 0.7500
# Epoch 29/60
# 30/30 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9708
# Epoch 00029: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.1157 - accuracy: 0.9708 - val_loss: 0.6146 - val_accuracy: 0.7143
# Epoch 30/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9875
# Epoch 00030: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0675 - accuracy: 0.9875 - val_loss: 0.5910 - val_accuracy: 0.7143
# Epoch 31/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9833
# Epoch 00031: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0776 - accuracy: 0.9833 - val_loss: 0.6414 - val_accuracy: 0.6964
# Epoch 32/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9958
# Epoch 00032: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0512 - accuracy: 0.9958 - val_loss: 0.4982 - val_accuracy: 0.7500
# Epoch 33/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9833
# Epoch 00033: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0484 - accuracy: 0.9833 - val_loss: 0.6443 - val_accuracy: 0.7143
# Epoch 34/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9917
# Epoch 00034: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0370 - accuracy: 0.9917 - val_loss: 0.5992 - val_accuracy: 0.8036
# Epoch 35/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9958
# Epoch 00035: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0290 - accuracy: 0.9958 - val_loss: 0.6649 - val_accuracy: 0.7679
# Epoch 36/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9958
# Epoch 00036: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0226 - accuracy: 0.9958 - val_loss: 0.6761 - val_accuracy: 0.7143
# Epoch 37/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.9875
# Epoch 00037: val_loss did not improve from 0.44921
# 30/30 [==============================] - 47s 2s/step - loss: 0.0332 - accuracy: 0.9875 - val_loss: 0.6815 - val_accuracy: 0.7679
# Epoch 38/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 0.9708
# Epoch 00038: val_loss did not improve from 0.44921
# 30/30 [==============================] - 47s 2s/step - loss: 0.0894 - accuracy: 0.9708 - val_loss: 0.7707 - val_accuracy: 0.6786
# Epoch 39/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9875
# Epoch 00039: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0560 - accuracy: 0.9875 - val_loss: 0.5751 - val_accuracy: 0.7143
# Epoch 40/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9958
# Epoch 00040: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0220 - accuracy: 0.9958 - val_loss: 0.6089 - val_accuracy: 0.8036
# Epoch 41/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9958
# Epoch 00041: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0202 - accuracy: 0.9958 - val_loss: 0.6337 - val_accuracy: 0.7679
# Epoch 42/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9958
# Epoch 00042: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0160 - accuracy: 0.9958 - val_loss: 0.5813 - val_accuracy: 0.8214
# Epoch 43/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9958
# Epoch 00043: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.7123 - val_accuracy: 0.8571
# Epoch 44/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9917
# Epoch 00044: val_loss did not improve from 0.44921
# 30/30 [==============================] - 47s 2s/step - loss: 0.0154 - accuracy: 0.9917 - val_loss: 0.5009 - val_accuracy: 0.8393
# Epoch 45/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9917
# Epoch 00045: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0186 - accuracy: 0.9917 - val_loss: 0.7571 - val_accuracy: 0.6786
# Epoch 46/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9958
# Epoch 00046: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.8489 - val_accuracy: 0.6964
# Epoch 47/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9958
# Epoch 00047: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0107 - accuracy: 0.9958 - val_loss: 0.7067 - val_accuracy: 0.7321
# Epoch 48/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9958
# Epoch 00048: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0081 - accuracy: 0.9958 - val_loss: 0.7308 - val_accuracy: 0.7679
# Epoch 49/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9958
# Epoch 00049: val_loss did not improve from 0.44921
# 30/30 [==============================] - 47s 2s/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.7016 - val_accuracy: 0.7143
# Epoch 50/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9917
# Epoch 00050: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0093 - accuracy: 0.9917 - val_loss: 0.7545 - val_accuracy: 0.7321
# Epoch 51/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9958
# Epoch 00051: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0088 - accuracy: 0.9958 - val_loss: 0.6267 - val_accuracy: 0.7321
# Epoch 52/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9958
# Epoch 00052: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0075 - accuracy: 0.9958 - val_loss: 0.7601 - val_accuracy: 0.7321
# Epoch 53/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9958
# Epoch 00053: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0070 - accuracy: 0.9958 - val_loss: 0.6850 - val_accuracy: 0.8036
# Epoch 54/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 00054: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.6388 - val_accuracy: 0.8571
# Epoch 55/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9958
# Epoch 00055: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0084 - accuracy: 0.9958 - val_loss: 0.8853 - val_accuracy: 0.7143
# Epoch 56/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9958
# Epoch 00056: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.7898 - val_accuracy: 0.7321
# Epoch 57/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9958
# Epoch 00057: val_loss did not improve from 0.44921
# 30/30 [==============================] - 47s 2s/step - loss: 0.0068 - accuracy: 0.9958 - val_loss: 0.8590 - val_accuracy: 0.8214
# Epoch 58/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9958
# Epoch 00058: val_loss did not improve from 0.44921
# 30/30 [==============================] - 47s 2s/step - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.7397 - val_accuracy: 0.8036
# Epoch 59/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9958
# Epoch 00059: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0075 - accuracy: 0.9958 - val_loss: 0.7736 - val_accuracy: 0.7500
# Epoch 60/60
# 30/30 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9958
# Epoch 00060: val_loss did not improve from 0.44921
# 30/30 [==============================] - 46s 2s/step - loss: 0.0080 - accuracy: 0.9958 - val_loss: 0.8410 - val_accuracy: 0.7143

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']


plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

model.save(f"drive/My Drive/svl-pac/checkpoints/{MODEL_NAME}/m1.h5")
